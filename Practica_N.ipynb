# %% [markdown]
# # Práctica

# %%
pip install pandas openpyxl
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openpyxl]
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# librerías
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
# Leer el archivo Excel
df = pd.read_excel('Archivos/censuspopdata.xlsx', engine='openpyxl')

# %%
# dimensiones del DataFrame
df.shape
# Out:
# (72864, 4)

# %%
# Columnas del DataFrame
df.columns
# Out:
# Index(['CensusTract', 'State', 'County', 'POP2010'], dtype='object')

# %%
# Primeras filas del DataFrame
df.head()
# Out:
#    CensusTract State   County  POP2010
# 0   1001020100    AL  Autauga     1912
# 1   1001020200    AL  Autauga     2170
# 2   1001020300    AL  Autauga     3373
# 3   1001020400    AL  Autauga     4386
# 4   1001020500    AL  Autauga    10766

# %%
# Agrupa los datos por estado y suma la población
state_population = df.groupby('State')['POP2010'].sum()

# %%
state_population
# Out:
# State
# AK      710231
# AL     4779736
# AR     2915918
# AZ     6392017
# CA    37253956
# CO     5029196
# CT     3574097
# DC      601723
# DE      897934
# FL    18801310
# GA     9687653
# HI     1360301
# IA     3046355
# ID     1567582
# IL    12830632
# IN     6483802
# KS     2853118
# KY     4339367
# LA     4533372
# MA     6547629
# MD     5773552
# ME     1328361
# MI     9883640
# MN     5303925
# MO     5988927
# MS     2967297
# MT      989415
# NC     9535483
# ND      672591
# NE     1826341
# NH     1316470
# NJ     8791894
# NM     2059179
# NV     2700551
# NY    19378102
# OH    11536504
# OK     3751351
# OR     3831074
# PA    12702379
# RI     1052567
# SC     4625364
# SD      814180
# TN     6346105
# TX    25145561
# UT     2763885
# VA     8001024
# VT      625741
# WA     6724540
# WI     5686986
# WV     1852994
# WY      563626
# Name: POP2010, dtype: int64

# %%
pip install wordcloud
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.6/27.6 MB 37.9 MB/s  0:00:00 43.6 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for wordcloud: filename=wordcloud-1.9.4-cp314-cp314-macosx_10_15_universal2.whl size=238811 sha256=d03bd432f4cc6e21bbd44bea013d25642a0aaa43fa973022c073e3512a7c24a2
#   Stored in directory: /Users/alonsodariopizarrolagunas/Library/Caches/pip/wheels/38/3b/19/154b2215b636aee485efaa8be305a2d22b0a1707516894200c
# Successfully built wordcloud
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
texto = """El análisis de datos se ha convertido en una disciplina fundamental en el mundo moderno. Empresas de todos los sectores buscan profesionales capaces de extraer valor y conocimiento de enormes volúmenes de información. La ciencia de datos, un campo interdisciplinario, combina estadísticas, informática y conocimiento de dominio para resolver problemas complejos. Python es el lenguaje preferido para muchos científicos de datos debido a su sintaxis sencilla y a un ecosistema robusto de librerías.

Entre las librerías más utilizadas se encuentran Pandas para la manipulación y análisis de datos, NumPy para el cálculo numérico eficiente, y Matplotlib y Seaborn para la visualización de datos. Jupyter Notebooks y JupyterLab son entornos interactivos excelentes para desarrollar y compartir análisis de datos, permitiendo combinar código, texto y visualizaciones en un solo documento. La exploración inicial de los datos, o Análisis Exploratorio de Datos (EDA), es crucial para entender las características de un dataset, identificar patrones, detectar anomalías y formular hipótesis.

El Machine Learning, una rama de la inteligencia artificial, se enfoca en el desarrollo de algoritmos que permiten a las computadoras aprender de los datos sin ser programadas explícitamente. Hay diferentes tipos de aprendizaje automático, incluyendo el aprendizaje supervisado, donde el modelo aprende de datos etiquetados para hacer predicciones, y el aprendizaje no supervisado, que busca patrones ocultos en datos sin etiquetar. Los modelos de clasificación y regresión son pilares del aprendizaje supervisado, mientras que el clustering es una técnica común en el aprendizaje no supervisado.

La visualización de datos juega un papel vital en la comunicación de resultados. Un buen gráfico puede revelar tendencias, correlaciones y valores atípicos que serían difíciles de detectar en tablas de números. Herramientas como Tableau, Power BI y librerías de Python como Plotly o Bokeh ofrecen capacidades avanzadas para crear cuadros de mando interactivos y reportes dinámicos. La narrativa de datos es el arte de contar historias convincentes con los datos, transformando números en insights accionables.

Big Data se refiere a conjuntos de datos tan grandes y complejos que los métodos tradicionales de procesamiento de datos no son adecuados. Requiere tecnologías y técnicas avanzadas para su almacenamiento, procesamiento y análisis. Apache Hadoop y Apache Spark son ejemplos de *frameworks* diseñados para manejar Big Data, permitiendo el procesamiento distribuido en *clusters* de computadoras. La escalabilidad es una consideración clave al trabajar con Big Data, asegurando que las soluciones puedan crecer con el volumen de datos.

La ética en el uso de datos y la privacidad son temas de creciente importancia. Los científicos de datos deben considerar el impacto social de sus modelos, la imparcialidad algorítmica y la protección de la información personal. Regulaciones como el GDPR (Reglamento General de Protección de Datos) y CCPA (California Consumer Privacy Act) establecen pautas estrictas sobre cómo las empresas pueden recopilar, procesar y almacenar datos de usuarios.

La inteligencia artificial (IA) abarca un amplio espectro de tecnologías y aplicaciones, desde el procesamiento del lenguaje natural (NLP) y la visión por computadora hasta los sistemas expertos y la robótica. El aprendizaje profundo (Deep Learning), un subcampo del Machine Learning, utiliza redes neuronales artificiales con múltiples capas (redes profundas) para modelar abstracciones de alto nivel en los datos. Ha logrado avances impresionantes en áreas como el reconocimiento de imágenes, el habla y la traducción automática.

La gestión de bases de datos es otra área crítica. SQL (Structured Query Language) sigue siendo el lenguaje estándar para interactuar con bases de datos relacionales como MySQL, PostgreSQL y SQL Server. Las bases de datos NoSQL, como MongoDB y Cassandra, ofrecen mayor flexibilidad y escalabilidad para ciertos tipos de datos y aplicaciones. La integración de datos y la limpieza de datos son tareas que consumen mucho tiempo pero son esenciales para la calidad de los análisis. Los datos ruidosos o incompletos pueden llevar a conclusiones erróneas.

Finalmente, la colaboración es clave en proyectos de ciencia de datos. Herramientas como Git y GitHub permiten a los equipos trabajar juntos de manera eficiente, gestionando versiones del código, fusionando cambios y revisando el trabajo de los demás. La comunicación efectiva entre científicos de datos, ingenieros y *stakeholders* del negocio es crucial para el éxito del proyecto. La experimentación constante, la iteración y la voluntad de aprender son características de un buen enfoque en la ciencia de datos. El futuro traerá más automatización y la necesidad de habilidades aún más sofisticadas en la interpretación y aplicación de estos avances tecnológicos. El ciclo de vida de un proyecto de datos implica la recolección, limpieza, análisis, modelado, despliegue y monitoreo continuo, cada etapa con sus propios desafíos y oportunidades. La capacidad de formular preguntas relevantes es tan importante como la capacidad de encontrar las respuestas. La innovación en este campo no se detiene, impulsando el desarrollo de nuevas técnicas y herramientas constantemente."""

# Crear la nube
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(texto)

# Mostrar la imagen
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")

# --- PASO CLAVE: Guardar la figura en la carpeta 'plato' ---
plt.tight_layout()
plt.savefig('Plots/frecuencia_palabras.png')

plt.show()
